# %%
#etquetas y leyendas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import jovian
np.random.seed(0)
df = pd.read_csv("C:/Python/Python38/base_datos_2008.csv", nrows = 1000000)
data = np.unique(df.DayOfWeek,return_counts=True)
labs = ["Lun","Mar","Mie","Jue","Vie","Sab","Dom"]
df = df.sample(frac=1).head(100)
data
# Out:
# (array([1, 2, 3, 4, 5, 6, 7], dtype=int64),
#  array([137229, 152498, 155928, 159416, 153724, 112352, 128853],
#        dtype=int64))

# %%
data = np.unique(df.Cancelled, return_counts = True)#resumen de los vuelos cancelados
data
# Out:
# (array([0, 1], dtype=int64), array([98858,  1142], dtype=int64))

# %%
plt.pie(x=data[1],
       labels = data[0])
plt.show()

# %%
plt.scatter(x=df.DayofMonth,y=df.ArrDelay, s = df.Distance)

# %%
plt=sns.barplot(x = labs, y = data[1])
plt.set(xlabel = "Dia de la semana", ylabel = "Numero de vuelos")
# Out:
# [Text(0, 0.5, 'Numero de vuelos'), Text(0.5, 0, 'Dia de la semana')]
