# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import jovian
df = pd.read_csv("C:/Python/Python38/base_datos_2008.csv")

# %%
df.dropna(inplace = True, subset = ["ArrDelay","DepDelay","Distance"])

# %%
sns.distplot(df["Distance"], kde=False, bins=100)

# %%
sns.kdeplot(df["ArrDelay"])
sns.kdeplot(df["DepDelay"])
plt.xlim([-300,300])
# Out:
# (-300, 300)

# %%
df2 = df[df["Origin"].isin(["ALT","HOU","IND"])].sample(frac = 1).head(500)
sns.boxplot(x ="DepDelay", y="Origin",data = df2)
ptl.xlim([-20,150])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0ca16c937c32> in <module>
#       1 df2 = df[df["Origin"].isin(["ALT","HOU","IND"])].sample(frac = 1).head(500)
#       2 sns.boxplot(x ="DepDelay", y="Origin",data = df2)
# ----> 3 ptl.xlim([-20,150])
#
# NameError: name 'ptl' is not defined

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/joanpellegrino04/visualizacion-de-datos
# 'https://jovian.ml/joanpellegrino04/visualizacion-de-datos'
