# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
vuelos = sns.load_dataset('flights')
vuelos.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
vuelos = vuelos.pivot('month', 'year', 'passengers')
vuelos
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(vuelos)#mapa de calor

# %%
sns.heatmap(vuelos, annot=True,fmt='d')#mapa de calor

# %%
valor_central = vuelos.loc['May'][1956]
valor_central
# Out:
# 318

# %%
sns.heatmap(vuelos,center=valor_central, annot=True, fmt='d', cbar_kws={'orientation':'horizontal'})#mapa de calor

# %%
lista_valores = np.random.randn(1000) #ejercicios crear lista de 1000 valores aleatorios que sigan una distribucion normal

# %%
lista_valores
# Out:
# array([-1.21144385e+00,  1.79712679e+00,  7.67157719e-01,  7.63060209e-01,
#        -3.92691323e-01, -1.07213050e-01, -4.03358906e-01,  1.03626230e+00,
#         5.30675423e-01,  1.51579035e+00, -1.03588931e+00,  1.01036491e+00,
#         1.28406504e-01, -1.18226289e+00,  3.33531099e-01, -1.88527840e-01,
#        -7.48362691e-01, -1.61993609e-01,  1.27406145e-01,  1.62655230e-01,
#        -9.60553782e-02, -7.58350400e-01,  2.05624057e+00, -6.83374699e-01,
#        -4.22687278e-01,  1.00022305e+00,  3.26829690e-01,  1.21024140e+00,
#        -1.33266114e-01, -1.19351708e+00,  1.41561534e+00, -9.54294831e-01,
#        -4.03644817e-01, -6.49794160e-01,  3.46536414e-01,  2.09314450e+00,
#        -2.20421623e-02,  1.31996168e+00,  5.10522005e-01,  1.41371963e-01,
#        -2.56332222e-01,  6.18982389e-01, -8.88512640e-01, -1.79466876e-01,
#        -4.60622158e-01, -1.73691084e+00,  7.44833433e-01,  9.37405551e-01,
# ...

# %%
plt.hist(lista_valores) #crear un histograma mediante matplotlib con la lista de valores
# Out:
# (array([  5.,  32.,  77., 156., 219., 215., 165.,  87.,  36.,   8.]),
#  array([-2.85654139, -2.29276579, -1.72899018, -1.16521457, -0.60143896,
#         -0.03766335,  0.52611225,  1.08988786,  1.65366347,  2.21743908,
#          2.78121469]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(lista_valores) #crear un diagrama de caja(donde se acomula el 50% de los valores) mediante seaborn
