# %%
import  pandas as pd
df = pd.read_csv("C:/Python/Python38/base_datos_2008.csv", nrows = 1e6)

# %%
df.head(10)#Diez primras filas
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# ...

# %%
df.drop(0)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1       2008      1           3          4    754.0         735   1002.0
# 2       2008      1           3          4    628.0         620    804.0
# 3       2008      1           3          4    926.0         930   1054.0
# 4       2008      1           3          4   1829.0        1755   1959.0
# 5       2008      1           3          4   1940.0        1915   2121.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999995  2008      2          12          2   1648.0        1655   1959.0
# 999996  2008      2          13          3   1647.0        1655   2013.0
# 999997  2008      2          14          4   1653.0        1655   2000.0
# 999998  2008      2          15          5   1650.0        1655   1951.0
# 999999  2008      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.tail() #Ultimas cinco filas
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 99995        2257            XE       7676  ...    4.0     17.0          0
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df = df.sample(frac = 1) #frac=1,mantiene todas las filas

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[2008, 1, 15, ..., nan, nan, nan],
#        [2008, 1, 18, ..., nan, nan, nan],
#        [2008, 1, 22, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 18, ..., nan, nan, nan],
#        [2008, 1, 31, ..., 0.0, 0.0, 39.0],
#        [2008, 1, 29, ..., nan, nan, nan]], dtype=object)

# %% [markdown]
# # filtrado

# %%
df["ArrDelay"].head(10) #Obtener columna de retraso de los vuelos(ArrDelay)

# %%
df[100:110]
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 100  2008      1           3          4    826.0         825    930.0
# 101  2008      1           3          4   2118.0        2015   2224.0
# 102  2008      1           3          4   1818.0        1740   1916.0
# 103  2008      1           3          4    650.0         650    748.0
# 104  2008      1           3          4   2146.0        2055   2250.0
# 105  2008      1           3          4   2241.0        1910   2340.0
# 106  2008      1           3          4   1409.0        1355   1513.0
# 107  2008      1           3          4   1100.0        1050   1157.0
# 108  2008      1           3          4   1306.0        1250   1406.0
# 109  2008      1           3          4   1726.0        1630   1832.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 100         925            WN        136  ...    2.0     16.0          0
# ...

# %%
df[df["ArrDelay"] > 60].head() #vuelos retrasados mas de 60 minutos
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 92032  2008      1          31          4   1513.0        1340   1613.0
# 99949  2008      1          22          2   1716.0        1500   1810.0
# 79250  2008      1          27          7   1955.0        1640   2050.0
# 60711  2008      1          21          1    711.0         640    931.0
# 97799  2008      1          25          5   1649.0        1515   1930.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 92032        1445            WN        812  ...    4.0     11.0          0
# 99949        1542            XE       7674  ...    5.0     18.0          0
# 79250        1740            WN        378  ...    7.0     10.0          0
# 60711         800            WN       1862  ...    5.0    104.0          0
# 97799        1808            XE        423  ...    6.0     10.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[df["Origin"]== "PDX"].head() #vuelos que salen de un cierto aeropuerto

# %%
df[(df["Origin"]== "PDX") & (df["ArrDelay"] > 60)].head() #Se aplica doble filtro
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 92922  2008      1          31          4   2230.0        2050   2332.0
# 7725   2008      1           5          6   1900.0        1740   2134.0
# 99684  2008      1          21          1   2014.0        1720   2307.0
# 59903  2008      1          21          1   2226.0        2050   2330.0
# 59923  2008      1          21          1   1245.0        1130   1359.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 92922        2150            WN       1231  ...    6.0      9.0          0
# 7725         2025            WN        159  ...    2.0     10.0          0
# 99684        2010            XE       7651  ...    7.0     12.0          0
# 59903        2150            WN       1231  ...    6.0      7.0          0
# 59923        1250            WN       1566  ...    5.0      7.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[df.Origin.isin(["PDX", "COS"])].head() #Escoger difrentes origenes a la vez.

# %%
df["Origin"]

# %%
df[pd.isna(df["ArrDelay"])].head() #obtener datos perdidos con funtion pandas

# %%
df["HoursDelay"]= round(df["ArrDelay"] / 60)#crear una columna nueva

# %%
del(df["HoursDelay"])

# %%
df.head()

# %%
df.drop(["Diverted", "Cancelled", "Year"], axis=1, inplace=True)#borrar varias columnas a la vez, lo ejecuta pero no guarda, se debe igualar

# %%
df.drop(0) # Borra la fila 0, solo ejecuta la instruccion, para guardar borrar se debe igualar la instrucción
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1           1           3          4    754.0         735   1002.0
# 2           1           3          4    628.0         620    804.0
# 3           1           3          4    926.0         930   1054.0
# 4           1           3          4   1829.0        1755   1959.0
# 5           1           3          4   1940.0        1915   2121.0
# ...       ...         ...        ...      ...         ...      ...
# 999995      2          12          2   1648.0        1655   1959.0
# 999996      2          13          3   1647.0        1655   2013.0
# 999997      2          14          4   1653.0        1655   2000.0
# 999998      2          15          5   1650.0        1655   1951.0
# 999999      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum TailNum  ...  Dest  Distance  \
# 1             1000            WN       3231  N772SW  ...   TPA       810
# ...

# %%
df.drop(range(0,100000), inplace=True)#eliminar muchas filas de un golpe

# %%
dfATL = df[df.Origin == "ATL"]
dfHOU = df[df.Origin == "HOU"] #Crear nuvas filas, nuevas bases de datos

# %%
newdf = dfATL.append(dfHOU) # esto suma los dos dataframe

# %%
newdf.Origin
# Out:
# 103149    ATL
# 103572    ATL
# 104019    ATL
# 104124    ATL
# 104485    ATL
#          ...
# 980261    HOU
# 980262    HOU
# 980263    HOU
# 980264    HOU
# 980265    HOU
# Name: Origin, Length: 68288, dtype: object

# %% [markdown]
# # gruopby

# %%
df.groupby(by = "DayOfWeek")["ArrDelay"].max() #por cadia dia de la semana ("DayOfWeek") el Retraso ("ArrDelay") maximo de vuelos
# Out:
# DayOfWeek
# 1    1146.0
# 2    1057.0
# 3    1357.0
# 4    1094.0
# 5    1357.0
# 6    1525.0
# 7    1166.0
# Name: ArrDelay, dtype: float64

# %%
df.groupby(by = "DayOfWeek")["ArrDelay"].describe() #resumen estadistico agrupado para cada uno de los dias de la semana
# Out:
#              count       mean        std   min   25%  50%   75%    max
# DayOfWeek
# 1          14349.0   4.568960  29.047008 -56.0  -9.0 -3.0   9.0  431.0
# 2          14471.0   0.446479  21.617710 -48.0 -10.0 -4.0   5.0  360.0
# 3          14504.0  -1.646511  18.464538 -48.0 -11.0 -5.0   3.0  422.0
# 4          16774.0  13.387922  38.490537 -45.0  -7.0  2.0  19.0  486.0
# 5          14350.0   7.684948  28.156892 -52.0  -7.0  0.0  14.0  364.0
# 6          11172.0   2.069280  27.866895 -49.0 -11.0 -4.0   6.0  500.0
# 7          13078.0  12.190625  41.925311 -57.0  -9.0  0.0  16.0  367.0

# %%
df.groupby(by = "DayOfWeek")["ArrDelay"].mean()# Calcula la media para la columna ArrDelay
# Out:
# DayOfWeek
# 1     4.568960
# 2     0.446479
# 3    -1.646511
# 4    13.387922
# 5     7.684948
# 6     2.069280
# 7    12.190625
# Name: ArrDelay, dtype: float64

# %%
df.groupby(by = "DayOfWeek")["ArrDelay", "DepDelay"].mean()# Calcula la media a dos columnas
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#             ArrDelay   DepDelay
# DayOfWeek
# 1          12.115087  13.376120
# 2          13.637012  13.695058
# 3           9.101139  10.653427
# 4          11.995864  12.540728
# 5          13.095501  14.021772
# 6           5.707830   8.647372
# 7          11.632100  13.547314

# %%
df.groupby(by = "DayOfWeek")["ArrDelay"].max()-df.groupby(by = "DayOfWeek")["ArrDelay"].min()#operacion de resta para max y min(rango de valores)
# Out:
# DayOfWeek
# 1    1226.0
# 2    1125.0
# 3    1432.0
# 4    1163.0
# 5    1443.0
# 6    1616.0
# 7    1245.0
# Name: ArrDelay, dtype: float64

# %%
dfATLHOU=df[df.Origin.isin(["ATL","HOU"])]#crear nuevo dataframe con vuelos de dos ciudades ATLANTA y HOUSTONG

# %%
#por cada dia de la semana aquellos vuelos que salen de atlanta y houstom y sus medias
#lo que permite comparar cual de las dos ciudades cuales vuelos llegan mas retrasados y en que dia las diferencias son mayores
dfATLHOU.groupby(by=["DayOfWeek", "Origin"])["ArrDelay"].mean()
# Out:
# DayOfWeek  Origin
# 1          ATL        7.367432
#            HOU       11.180751
# 2          ATL        9.706690
#            HOU       12.610830
# 3          ATL       12.433992
#            HOU       11.487395
# 4          ATL       11.527772
#            HOU       18.631061
# 5          ATL       11.571790
#            HOU       12.462759
# 6          ATL        6.264876
#            HOU        2.287234
# 7          ATL       12.093200
#            HOU       11.420108
# Name: ArrDelay, dtype: float64

# %%
dfATLHOU.Origin
# Out:
# 49564    HOU
# 78125    HOU
# 91582    HOU
# 84676    HOU
# 42688    HOU
#         ...
# 12754    HOU
# 12888    HOU
# 58609    HOU
# 91605    HOU
# 26535    HOU
# Name: Origin, Length: 3825, dtype: object

# %%
df.groupby(by = "DayOfWeek")["ArrDelay"].mean()
# Out:
# DayOfWeek
# 1     4.568960
# 2     0.446479
# 3    -1.646511
# 4    13.387922
# 5     7.684948
# 6     2.069280
# 7    12.190625
# Name: ArrDelay, dtype: float64

# %% [markdown]
# # datos duplicados y perdidos

# %%
dfduplicate = df.append(df) #eliminar datos duplicados

# %%
dfduplicate = dfduplicate.sample(frac=1)#eliminar datos duplicados

# %%
dfclean = dfduplicate.drop_duplicates()#eliminar datos duplicados

# %%
len(dfclean)==len(df)
# Out:
# False

# %%
len(dfclean)
# Out:
# 999996

# %%
len(df)
# Out:
# 1000000

# %%
dfclean.drop_duplicates(subset="DayofMonth") #eliminar datos duplicados columna especifica
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 135798      1          10          4   1118.0        1117   1429.0
# 554613      1          16          3   1808.0        1815   2103.0
# 443268      1           2          3    552.0         600    836.0
# 314127      1          24          4    817.0         820   1145.0
# 252459      1          13          7   1809.0        1815   1852.0
# 703335      2           1          5   1616.0        1310   2114.0
# 331807      1          30          3   1054.0        1000   1202.0
# 763915      2          28          4   1355.0        1330   1555.0
# 408243      1           3          4   1303.0        1300   1402.0
# 512553      1          11          5   1345.0        1345   1603.0
# 439553      1          21          1    914.0         918   1203.0
# 329670      1           4          5   1029.0        1030   1210.0
# 235766      1          29          2    950.0         955   1228.0
# ...

# %%
dfclean.head()
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 894638  2008      2          18          1   2302.0        2259      1.0
# 33437   2008      1          13          7   1308.0        1300   1614.0
# 108687  2008      1           6          7   1910.0        1915   2221.0
# 100349  2008      1          30          3   1722.0        1725   1846.0
# 803906  2008      2          25          1    552.0         600    600.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 894638           4            DL        895  ...    9.0     16.0          0
# 33437         1610            WN        190  ...    4.0     10.0          0
# 108687        2249            XE       2521  ...    9.0     10.0          0
# 100349        1900            XE       7739  ...    4.0     13.0          0
# 803906         616            OO       5901  ...   10.0     14.0          0
#
# ...

# %%
#gestionar datos faltantes
df.dropna() #el resultado mustra que no hay datos fltntes
# Out:
# Empty DataFrame
# Columns: [Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, ArrTime, CRSArrTime, UniqueCarrier, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiIn, TaxiOut, CancellationCode, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.dropna(subset=["CancellationCode"]) #filtrar por una columna en concreto
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178         1           3          4      NaN         700      NaN
# 373         1           3          4      NaN        1100      NaN
# 399         1           3          4      NaN         905      NaN
# 401         1           3          4      NaN        1620      NaN
# 415         1           3          4      NaN        1930      NaN
# ...       ...         ...        ...      ...         ...      ...
# 999913      2          11          1      NaN         855      NaN
# 999919      2          17          7      NaN         855      NaN
# 999961      2          17          7      NaN        1445      NaN
# 999971      2          22          5      NaN        1235      NaN
# 999999      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum TailNum  ...  Dest  Distance  \
# 178            830            WN        126     NaN  ...   OAK       407
# ...
