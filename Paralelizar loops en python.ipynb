# %%
import pandas as pd
import numpy as np
from joblib import parallel, delayed
df = pd.read_csv("C:/Python/Python38/base_datos_2008.csv", nrows = 100000)

# %%
df_sub = df[['CarrierDelay','WeatherDelay', 'SecurityDelay','LateAircraftDelay']]
df_sub.head(10)
# Out:
#    CarrierDelay  WeatherDelay  SecurityDelay  LateAircraftDelay
# 0           NaN           NaN            NaN                NaN
# 1           NaN           NaN            NaN                NaN
# 2           NaN           NaN            NaN                NaN
# 3           NaN           NaN            NaN                NaN
# 4           2.0           0.0            0.0               32.0
# 5           NaN           NaN            NaN                NaN
# 6          10.0           0.0            0.0               47.0
# 7           NaN           NaN            NaN                NaN
# 8           NaN           NaN            NaN                NaN
# 9           NaN           NaN            NaN                NaN
